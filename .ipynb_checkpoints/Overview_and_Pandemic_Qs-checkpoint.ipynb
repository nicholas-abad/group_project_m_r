# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
joined_15 = pd.read_csv("/Users/vardr.DESKTOP-R06GCLK/CodeOp_Data_Analytics_Mod3on/Group_Project/Preprocessed_files/joined_file_1_3_4.csv")

# %%
joined_15
# Out:
#      time_period geographic_level region_code               region_name  \
# 0     2018-01-01  Local authority   E13000002              Outer London
# 1     2018-01-01  Local authority   E13000002              Outer London
# 2     2018-01-01  Local authority   E12000003  Yorkshire and The Humber
# 3     2018-01-01  Local authority   E12000009                South West
# 4     2018-01-01  Local authority   E12000006           East of England
# ...          ...              ...         ...                       ...
# 3184  2024-01-01  Local authority   E12000002                North West
# 3185  2024-01-01  Local authority   E12000008                South East
# 3186  2024-01-01  Local authority   E12000005             West Midlands
# 3187  2024-01-01  Local authority   E12000005             West Midlands
# 3188  2024-01-01  Local authority   E12000003  Yorkshire and The Humber
#
#      new_la_code                       la_name     entitlement_type  \
# ...

# %%
joined_15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3189 entries, 0 to 3188
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   time_period                   3189 non-null   object
#  1   geographic_level              3189 non-null   object
#  2   region_code                   3189 non-null   object
#  3   region_name                   3189 non-null   object
#  4   new_la_code                   3189 non-null   object
#  5   la_name                       3189 non-null   object
#  6   entitlement_type              3189 non-null   object
#  7   age                           3189 non-null   object
#  8   number_children               3189 non-null   int64
#  9   number_eligible_children      3189 non-null   int64
#  10  percentage_eligible_children  3189 non-null   float64
#  11  number_children_dis           1063 non-null   float64
# ...

# %%
joined_15["time_period"] = pd.to_datetime(joined_15["time_period"], format = "%Y-%m-%d")

# %%
joined_15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3189 entries, 0 to 3188
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   time_period                   3189 non-null   datetime64[ns]
#  1   geographic_level              3189 non-null   object
#  2   region_code                   3189 non-null   object
#  3   region_name                   3189 non-null   object
#  4   new_la_code                   3189 non-null   object
#  5   la_name                       3189 non-null   object
#  6   entitlement_type              3189 non-null   object
#  7   age                           3189 non-null   object
#  8   number_children               3189 non-null   int64
#  9   number_eligible_children      3189 non-null   int64
#  10  percentage_eligible_children  3189 non-null   float64
#  11  number_children_dis           1063 non-null   float64
# ...

# %%
joined_15.to_csv("/Users/vardr.DESKTOP-R06GCLK/CodeOp_Data_Analytics_Mod3on/Group_Project/Preprocessed_files/joined1_3_4_15_hours.csv", sep=",", index=False, encoding="utf8")

# %% [markdown]
# ## Pandemic Research - % of eligible children enrolled from 2018 to 2024

# %%
eligible_children = joined_15.loc[joined_15["age"] == '3 and 4-year-olds', ["time_period", "percentage_eligible_children"]]

# %%
eligible_children
# Out:
#      time_period  percentage_eligible_children
# 1063  2018-01-01                          87.3
# 1064  2018-01-01                          82.3
# 1065  2018-01-01                          96.1
# 1066  2018-01-01                          99.9
# 1067  2018-01-01                          98.1
# ...          ...                           ...
# 2121  2024-01-01                          98.7
# 2122  2024-01-01                         102.1
# 2123  2024-01-01                          95.7
# 2124  2024-01-01                          97.2
# 2125  2024-01-01                          95.7
#
# [1063 rows x 2 columns]

# %%
sns.lineplot(data= eligible_children, x="time_period", y ="percentage_eligible_children")
plt.title("Percentage of Eligible Children Registered")
plt.xlabel("Year")
plt.ylabel("Percentage Registered")

# How could I label the data points for each year?
# Out:
# Text(0, 0.5, 'Percentage Registered')

# %%
registered = pd.read_csv("/Users/vardr.DESKTOP-R06GCLK/CodeOp_Data_Analytics_Mod3on/Group_Project/Preprocessed_files/children_registered_2.csv")

# %%
registered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29764 entries, 0 to 29763
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   time_period          29764 non-null  object
#  1   geographic_level     29764 non-null  object
#  2   region_code          29764 non-null  object
#  3   region_name          29764 non-null  object
#  4   new_la_code          29764 non-null  object
#  5   la_name              29764 non-null  object
#  6   entitlement_type     29764 non-null  object
#  7   provider_type_group  29764 non-null  object
#  8   provider_type        29764 non-null  object
#  9   year_group           29764 non-null  object
#  10  age                  29764 non-null  object
#  11  number_children      29764 non-null  float64
#  12  number_providers     29764 non-null  float64
# dtypes: float64(2), object(11)
# memory usage: 3.0+ MB

# %%
registered
# Out:
#       time_period geographic_level region_code   region_name new_la_code  \
# 0      2024-01-01  Local authority   E12000001    North East   E06000047
# 1      2024-01-01  Local authority   E12000001    North East   E06000047
# 2      2024-01-01  Local authority   E12000001    North East   E06000047
# 3      2024-01-01  Local authority   E12000001    North East   E06000047
# 4      2024-01-01  Local authority   E12000001    North East   E06000047
# ...           ...              ...         ...           ...         ...
# 29759  2018-01-01  Local authority   E13000002  Outer London   E09000031
# 29760  2018-01-01  Local authority   E13000002  Outer London   E09000031
# 29761  2018-01-01  Local authority   E13000002  Outer London   E09000031
# 29762  2018-01-01  Local authority   E13000002  Outer London   E09000031
# 29763  2018-01-01  Local authority   E13000002  Outer London   E09000031
#
#               la_name     entitlement_type  \
# 0       County Durham  15-hour entitlement
# ...

# %%
registered["time_period"] = pd.to_datetime(registered["time_period"], format = "%Y-%m-%d")

# %%
registered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29764 entries, 0 to 29763
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   time_period          29764 non-null  datetime64[ns]
#  1   geographic_level     29764 non-null  object
#  2   region_code          29764 non-null  object
#  3   region_name          29764 non-null  object
#  4   new_la_code          29764 non-null  object
#  5   la_name              29764 non-null  object
#  6   entitlement_type     29764 non-null  object
#  7   provider_type_group  29764 non-null  object
#  8   provider_type        29764 non-null  object
#  9   year_group           29764 non-null  object
#  10  age                  29764 non-null  object
#  11  number_children      29764 non-null  float64
#  12  number_providers     29764 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(10)
# memory usage: 3.0+ MB

# %%
registered["age"].value_counts(dropna=False)
# Out:
# age
# 3-year-olds    14882
# 4-year-olds    14882
# Name: count, dtype: int64

# %%
registered[["age", "time_period"]].value_counts()
# Out:
# age          time_period
# 4-year-olds  2024-01-01     2142
# 3-year-olds  2024-01-01     2142
#              2023-01-01     2128
#              2022-01-01     2128
#              2018-01-01     2128
#              2019-01-01     2128
# 4-year-olds  2023-01-01     2128
#              2022-01-01     2128
#              2019-01-01     2128
#              2018-01-01     2128
# 3-year-olds  2020-01-01     2114
#              2021-01-01     2114
# 4-year-olds  2020-01-01     2114
#              2021-01-01     2114
# Name: count, dtype: int64

# %%
joined_15["age"].value_counts(dropna=False)
# Out:
# age
# 3-year-olds          1063
# 3 and 4-year-olds    1063
# 4-year-olds          1063
# Name: count, dtype: int64

# %% [markdown]
# ## Pandemic Research - Create subset for 3 year olds and plot line graph by provider_type by year

# %%
providers_3_year_olds = registered.loc[registered["age"] == '3-year-olds', ["time_period", "provider_type", "number_children"]]

# %%
providers_3_year_olds = pd.DataFrame(registered.loc[registered["age"] == '3-year-olds', ["time_period", "provider_type","number_children"]])

# %%
providers_3_year_olds
# Out:
#       time_period                        provider_type  number_children
# 0      2024-01-01  All private and voluntary providers           2140.0
# 2      2024-01-01  All private and voluntary providers           1389.0
# 4      2024-01-01                  Independent schools             21.0
# 6      2024-01-01                  Independent schools              4.0
# 8      2024-01-01                         Childminders            102.0
# ...           ...                                  ...              ...
# 29754  2018-01-01         State-funded primary schools            254.0
# 29756  2018-01-01       State-funded secondary schools             83.0
# 29758  2018-01-01       State-funded secondary schools             17.0
# 29760  2018-01-01                      Special schools              4.0
# 29762  2018-01-01                      Special schools              0.0
#
# [14882 rows x 3 columns]

# %%
# summing the number of children per year and provider_type
providers_3_year_olds = providers_3_year_olds.groupby(
    [providers_3_year_olds['time_period'].dt.year, 'provider_type']
)['number_children'].sum().reset_index()

providers_3_year_olds
# Out:
#     time_period                        provider_type  number_children
# 0          2018  All private and voluntary providers         544415.0
# 1          2018                         Childminders          30521.0
# 2          2018                  Independent schools          14645.0
# 3          2018                      Special schools            968.0
# 4          2018         State-funded nursery schools          30289.0
# 5          2018         State-funded primary schools         220805.0
# 6          2018       State-funded secondary schools           2956.0
# 7          2019  All private and voluntary providers         553316.0
# 8          2019                         Childminders          33389.0
# 9          2019                  Independent schools          15235.0
# 10         2019                      Special schools            877.0
# 11         2019         State-funded nursery schools          30425.0
# ...

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(
    data = providers_3_year_olds,
    x='time_period',
    y='number_children',
    hue='provider_type',
    marker='o'
)

plt.title('3-Year-Olds by Provider Type (2018-2024)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Children', fontsize=12)
plt.legend(title='Provider Type', fontsize=10)

# %% [markdown]
# ## Pandemic Research - providers by 15 hours entitlement by year

# %%
providers_entitlement_15_hours = pd.DataFrame(registered.loc[registered["entitlement_type"] == '15-hour entitlement', ["time_period", "provider_type","number_children"]])

# %%
providers_entitlement_15_hours
# Out:
#       time_period                        provider_type  number_children
# 0      2024-01-01  All private and voluntary providers           2140.0
# 1      2024-01-01  All private and voluntary providers            692.0
# 4      2024-01-01                  Independent schools             21.0
# 5      2024-01-01                  Independent schools             33.0
# 8      2024-01-01                         Childminders            102.0
# ...           ...                                  ...              ...
# 29753  2018-01-01         State-funded primary schools           2970.0
# 29756  2018-01-01       State-funded secondary schools             83.0
# 29757  2018-01-01       State-funded secondary schools            118.0
# 29760  2018-01-01                      Special schools              4.0
# 29761  2018-01-01                      Special schools             18.0
#
# [14882 rows x 3 columns]

# %%
# summing the number of children receiving 15 hours entitlement by provider_type
providers_entitlement_15_hours = providers_entitlement_15_hours.groupby(
    [providers_entitlement_15_hours['time_period'].dt.year, 'provider_type']
)['number_children'].sum().reset_index()

providers_entitlement_15_hours
# Out:
#     time_period                        provider_type  number_children
# 0          2018  All private and voluntary providers         508436.0
# 1          2018                         Childminders          18188.0
# 2          2018                  Independent schools          26142.0
# 3          2018                      Special schools           4112.0
# 4          2018         State-funded nursery schools          33473.0
# 5          2018         State-funded primary schools         684697.0
# 6          2018       State-funded secondary schools           9584.0
# 7          2019  All private and voluntary providers         507936.0
# 8          2019                         Childminders          20347.0
# 9          2019                  Independent schools          26700.0
# 10         2019                      Special schools           4016.0
# 11         2019         State-funded nursery schools          32603.0
# ...

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(
    data = providers_entitlement_15_hours,
    x='time_period',
    y='number_children',
    hue='provider_type',
    marker='o'
)

plt.title('Provider Type by 15 Hours Entitlement (2018-2024)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Children', fontsize=12)
plt.legend(title='Provider Type', fontsize=10)

# %% [markdown]
# ## Pandemic Research - providers by 30 hours entitlement by year

# %%
providers_entitlement_30_hours = pd.DataFrame(registered.loc[registered["entitlement_type"] == '30-hour entitlement', ["time_period", "provider_type","number_children"]])

# %%
providers_entitlement_30_hours
# Out:
#       time_period                        provider_type  number_children
# 2      2024-01-01  All private and voluntary providers           1389.0
# 3      2024-01-01  All private and voluntary providers            462.0
# 6      2024-01-01                  Independent schools              4.0
# 7      2024-01-01                  Independent schools              7.0
# 10     2024-01-01                         Childminders            122.0
# ...           ...                                  ...              ...
# 29755  2018-01-01         State-funded primary schools            108.0
# 29758  2018-01-01       State-funded secondary schools             17.0
# 29759  2018-01-01       State-funded secondary schools              8.0
# 29762  2018-01-01                      Special schools              0.0
# 29763  2018-01-01                      Special schools              0.0
#
# [14882 rows x 3 columns]

# %%
# summing the number of children receiving 15 hours entitlement by provider_type
providers_entitlement_30_hours = providers_entitlement_30_hours.groupby(
    [providers_entitlement_30_hours['time_period'].dt.year, 'provider_type']
)['number_children'].sum().reset_index()

providers_entitlement_30_hours
# Out:
#     time_period                        provider_type  number_children
# 0          2018  All private and voluntary providers         218412.0
# 1          2018                         Childminders          20486.0
# 2          2018                  Independent schools           3847.0
# 3          2018                      Special schools             24.0
# 4          2018         State-funded nursery schools           8882.0
# 5          2018         State-funded primary schools          44803.0
# 6          2018       State-funded secondary schools            470.0
# 7          2019  All private and voluntary providers         235488.0
# 8          2019                         Childminders          22668.0
# 9          2019                  Independent schools           4611.0
# 10         2019                      Special schools             27.0
# 11         2019         State-funded nursery schools           9639.0
# ...

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(
    data = providers_entitlement_30_hours,
    x='time_period',
    y='number_children',
    hue='provider_type',
    marker='o'
)

plt.title('Provider Type by 30 Hours Entitlement (2018-2024)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Children', fontsize=12)
plt.legend(title='Provider Type', fontsize=10)

# %% [markdown]
# ## Pandemic Research - provider type by year for 4 year olds

# %%
providers_4_year_olds = pd.DataFrame(registered.loc[registered["age"] == '4-year-olds', ["time_period", "provider_type","number_children"]])

# %%
providers_4_year_olds
# Out:
#       time_period                        provider_type  number_children
# 1      2024-01-01  All private and voluntary providers            692.0
# 3      2024-01-01  All private and voluntary providers            462.0
# 5      2024-01-01                  Independent schools             33.0
# 7      2024-01-01                  Independent schools              7.0
# 9      2024-01-01                         Childminders             19.0
# ...           ...                                  ...              ...
# 29755  2018-01-01         State-funded primary schools            108.0
# 29757  2018-01-01       State-funded secondary schools            118.0
# 29759  2018-01-01       State-funded secondary schools              8.0
# 29761  2018-01-01                      Special schools             18.0
# 29763  2018-01-01                      Special schools              0.0
#
# [14882 rows x 3 columns]

# %%
# summing the number of children per year and provider_type
providers_4_year_olds = providers_4_year_olds.groupby(
    [providers_4_year_olds['time_period'].dt.year, 'provider_type']
)['number_children'].sum().reset_index()

# %%
providers_4_year_olds
# Out:
#     time_period                        provider_type  number_children
# 0          2018  All private and voluntary providers         182433.0
# 1          2018                         Childminders           8153.0
# 2          2018                  Independent schools          15344.0
# 3          2018                      Special schools           3168.0
# 4          2018         State-funded nursery schools          12066.0
# 5          2018         State-funded primary schools         508695.0
# 6          2018       State-funded secondary schools           7098.0
# 7          2019  All private and voluntary providers         190108.0
# 8          2019                         Childminders           9626.0
# 9          2019                  Independent schools          16076.0
# 10         2019                      Special schools           3166.0
# 11         2019         State-funded nursery schools          11817.0
# ...

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(
    data = providers_4_year_olds,
    x='time_period',
    y='number_children',
    hue='provider_type',
    marker='o'
)

plt.title('4-Year-Olds by Provider Type (2018-2024)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Children', fontsize=12)
plt.legend(title='Provider Type', fontsize=10)

# %% [markdown]
# ## Pandemic Research - Plotting Number of Children (total) by Provider type by Year (all ages, all entitlements)

# %%
# Filter data for years 2018 to 2024
filtered_data = registered[(registered['time_period'] >= '2018-01-01') & (registered['time_period'] <= '2024-12-31')]

# %%
# Group by time_period and provider_type, summing the number_child column
grouped_data = (
    filtered_data.groupby(['time_period', 'provider_type'])['number_children']
    .sum()
    .reset_index()
)

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(
    data=grouped_data,
    x='time_period',
    y='number_children',
    hue='provider_type',
    marker='o'
)

plt.title('Number of Children by Provider Type (2018-2024)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Children', fontsize=12)
plt.legend(title='Provider Type', fontsize=10)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

# %% [markdown]
# ## Making a box plot of % eligible children enrolled per year (2020, 2021, 2022) per region

# %%
percent_eligible_per_region_2019 = pd.DataFrame(joined_15.loc[(joined_15["time_period"] == '2019') & (joined_15["age"] == '3 and 4-year-olds'), ["region_name","percentage_eligible_children"]])

# %%
percent_eligible_per_region_2019
# Out:
#                    region_name  percentage_eligible_children
# 1215              Outer London                          87.0
# 1216              Outer London                          82.3
# 1217  Yorkshire and The Humber                          95.4
# 1218                South West                          99.0
# 1219           East of England                          98.2
# ...                        ...                           ...
# 1362                North West                          97.6
# 1363                South East                         103.1
# 1364             West Midlands                          88.9
# 1365             West Midlands                          98.0
# 1366  Yorkshire and The Humber                         100.6
#
# [152 rows x 2 columns]

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(
    data= percent_eligible_per_region_2019, 
    x = "percentage_eligible_children",
    y = "region_name",
    hue = "region_name"
)

plt.title('Percentage of Eligible 3 and 4-Year-Olds Enrolled in Childcare (2019)', fontsize=14)
plt.xlabel('Percentage of Eligible Children', fontsize=12)
plt.ylabel('Region', fontsize=12)
# Out:
# Text(0, 0.5, 'Region')

# %%
percent_eligible_per_region_2020 = pd.DataFrame(joined_15.loc[(joined_15["time_period"] == '2020') & (joined_15["age"] == '3 and 4-year-olds'), ["region_name","percentage_eligible_children"]])

# %%
percent_eligible_per_region_2020
# Out:
#                    region_name  percentage_eligible_children
# 1367              Outer London                          87.9
# 1368              Outer London                          81.4
# 1369  Yorkshire and The Humber                          95.4
# 1370                South West                          98.6
# 1371           East of England                          94.9
# ...                        ...                           ...
# 1513                North West                          96.2
# 1514                South East                          98.9
# 1515             West Midlands                          89.9
# 1516             West Midlands                          97.4
# 1517  Yorkshire and The Humber                          97.1
#
# [151 rows x 2 columns]

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(
    data= percent_eligible_per_region_2020, 
    x = "percentage_eligible_children",
    y = "region_name",
    hue = "region_name"
)

plt.title('Percentage of Eligible 3 and 4-Year-Olds Enrolled in Childcare (2020)', fontsize=14)
plt.xlabel('Percentage of Eligible Children', fontsize=12)
plt.ylabel('Region', fontsize=12)
# Out:
# Text(0, 0.5, 'Region')

# %%
percent_eligible_per_region_2021 = pd.DataFrame(joined_15.loc[(joined_15["time_period"] == '2021') & (joined_15["age"] == '3 and 4-year-olds'), ["region_name","percentage_eligible_children"]])

# %%
percent_eligible_per_region_2021
# Out:
#                    region_name  percentage_eligible_children
# 1518              Outer London                          83.9
# 1519              Outer London                          76.1
# 1520  Yorkshire and The Humber                          91.3
# 1521                South West                          93.3
# 1522           East of England                          88.8
# ...                        ...                           ...
# 1664                North West                          93.2
# 1665                South East                          97.1
# 1666             West Midlands                          86.6
# 1667             West Midlands                          93.6
# 1668  Yorkshire and The Humber                          92.5
#
# [151 rows x 2 columns]

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(
    data= percent_eligible_per_region_2021, 
    x = "percentage_eligible_children",
    y = "region_name",
    hue = "region_name"
)

plt.title('Percentage of Eligible 3-and 4-year-olds Enrolled in Childcare (2021)', fontsize=14)
plt.xlabel('Percentage of Eligible Children', fontsize=12)
plt.ylabel('Region', fontsize=12)
# Out:
# Text(0, 0.5, 'Region')

# %%
percent_eligible_per_region_2022 = pd.DataFrame(joined_15.loc[(joined_15["time_period"] == '2022') & (joined_15["age"] == '3 and 4-year-olds'), ["region_name","percentage_eligible_children"]])

# %%
percent_eligible_per_region_2022
# Out:
#                    region_name  percentage_eligible_children
# 1669              Outer London                          86.7
# 1670              Outer London                          81.0
# 1671  Yorkshire and The Humber                          93.4
# 1672                South West                          95.0
# 1673           East of England                          94.0
# ...                        ...                           ...
# 1816                North West                          95.6
# 1817                South East                         103.3
# 1818             West Midlands                          89.6
# 1819             West Midlands                          97.3
# 1820  Yorkshire and The Humber                          95.9
#
# [152 rows x 2 columns]

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(
    data= percent_eligible_per_region_2022, 
    x = "percentage_eligible_children",
    y = "region_name",
    hue = "region_name"
)

plt.title('Percentage of Eligible 3 and 4-year-olds Enrolled in Childcare (2022)', fontsize=14)
plt.xlabel('Percentage of Eligible Children', fontsize=12)
plt.ylabel('Region', fontsize=12)
# Out:
# Text(0, 0.5, 'Region')

# %% [markdown]
# ## Percentage of Eligible 3 year olds per Region in 2020 and 2021

# %%
percent_eligible_3YR_per_region_2020 = pd.DataFrame(joined_15.loc[(joined_15["time_period"] == '2020') & (joined_15["age"] == '3-year-olds'), ["region_name","percentage_eligible_children"]])

# %%
percent_eligible_3YR_per_region_2020
# Out:
#                   region_name  percentage_eligible_children
# 304              Outer London                          85.2
# 305              Outer London                          77.9
# 306  Yorkshire and The Humber                          94.2
# 307                South West                          97.1
# 308           East of England                          92.6
# ..                        ...                           ...
# 450                North West                          92.1
# 451                South East                          94.3
# 452             West Midlands                          87.4
# 453             West Midlands                          96.8
# 454  Yorkshire and The Humber                          95.2
#
# [151 rows x 2 columns]

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(
    data= percent_eligible_3YR_per_region_2020, 
    x = "percentage_eligible_children",
    y = "region_name",
    hue = "region_name"
)

plt.title('Percentage of Eligible 3-Year-Olds Enrolled in Childcare (2020)', fontsize=14)
plt.xlabel('Percentage of Eligible Children', fontsize=12)
plt.ylabel('Region', fontsize=12)
# Out:
# Text(0, 0.5, 'Region')

# %%
percent_eligible_3YR_per_region_2021 = pd.DataFrame(joined_15.loc[(joined_15["time_period"] == '2021') & (joined_15["age"] == '3-year-olds'), ["region_name","percentage_eligible_children"]])

# %%
percent_eligible_3YR_per_region_2021
# Out:
#                   region_name  percentage_eligible_children
# 455              Outer London                          77.4
# 456              Outer London                          71.8
# 457  Yorkshire and The Humber                          87.3
# 458                South West                          92.1
# 459           East of England                          83.0
# ..                        ...                           ...
# 601                North West                          92.1
# 602                South East                          95.7
# 603             West Midlands                          81.1
# 604             West Midlands                          90.7
# 605  Yorkshire and The Humber                          91.7
#
# [151 rows x 2 columns]

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(
    data= percent_eligible_3YR_per_region_2021, 
    x = "percentage_eligible_children",
    y = "region_name",
    hue = "region_name"
)

plt.title('Percentage of Eligible 3-Year-Olds Enrolled in Childcare (2021)', fontsize=14)
plt.xlabel('Percentage of Eligible Children', fontsize=12)
plt.ylabel('Region', fontsize=12)
# Out:
# Text(0, 0.5, 'Region')

# %% [markdown]
# ## Checking out outliers in Inner London Region

# %%
joined_15.loc[(joined_15["time_period"] == '2020') & (joined_15["region_name"] == 'Inner London'), ["la_name", "age", "percentage_eligible_children"]]
# Out:
#                      la_name                age  percentage_eligible_children
# 325                   Camden        3-year-olds                          63.1
# 329           City of London        3-year-olds                          71.3
# 350                  Hackney        3-year-olds                          84.7
# 352   Hammersmith and Fulham        3-year-olds                          77.6
# 354                 Haringey        3-year-olds                          78.0
# 364                Islington        3-year-olds                          83.7
# 365   Kensington and Chelsea        3-year-olds                          84.2
# 371                  Lambeth        3-year-olds                          83.8
# 376                 Lewisham        3-year-olds                          74.2
# 386                   Newham        3-year-olds                          80.1
# 421                Southwark        3-year-olds                          80.3
# ...

# %% [markdown]
# ### Note: the incredibly low enrollment in the city of london for 4 year olds may be to do with the fact that a) the borough area is geographically extremely small b)the area is mostly financial and may not have much choice in schools c) the children may be enrolled in a neighbouring local authority. Property is extremely expensive here so it is unlikely to be a result of poverty.

# %% [markdown]
# ## Checking out outliers in South West Region

# %%
joined_15.loc[(joined_15["time_period"] == '2020') & (joined_15["region_name"] == 'South West'), ["la_name", "age", "percentage_eligible_children"]]
# Out:
#                                   la_name                age  \
# 307          Bath and North East Somerset        3-year-olds
# 314   Bournemouth, Christchurch and Poole        3-year-olds
# 319                      Bristol, City of        3-year-olds
# 330                              Cornwall        3-year-olds
# 338                                 Devon        3-year-olds
# 340                                Dorset        3-year-olds
# 348                       Gloucestershire        3-year-olds
# 363                       Isles of Scilly        3-year-olds
# 390                        North Somerset        3-year-olds
# 400                              Plymouth        3-year-olds
# 416                              Somerset        3-year-olds
# 417                 South Gloucestershire        3-year-olds
# 431                               Swindon        3-year-olds
# 435                                Torbay        3-year-olds
# ...

# %% [markdown]
# ### NOTE: The Isles of Scilly are a group of islands off the coast of Cornwall in the far south west. The possible reasons behind this need further research as this is really interesting. However, the value in 2020 look really off and is throwing off the graphs so I think it should be removed (as it could be incorrect)

# %%
joined_15.loc[(joined_15["time_period"] == '2020') & (joined_15["la_name"] == 'Isles of Scilly'), ["age", "percentage_eligible_children"]]
# Out:
#                     age  percentage_eligible_children
# 363         3-year-olds                         174.6
# 1426  3 and 4-year-olds                         137.9
# 2489        4-year-olds                         114.8

# %%
#removing values for percentage_eligible_children for 3 year olds and 3 and 4 year olds as it is used in the calculation
joined_15.loc[363, 'percentage_eligible_children'] = np.nan

# %%
joined_15.loc[363]['percentage_eligible_children']
# Out:
# np.float64(nan)

# %%
joined_15.loc[1426, 'percentage_eligible_children'] = np.nan

# %%
joined_15.loc[363]['percentage_eligible_children']
# Out:
# np.float64(nan)

# %%
joined_15.loc[(joined_15["time_period"] == '2020') & (joined_15["region_name"] == 'South West'), ["la_name", "age", "percentage_eligible_children"]]
# Out:
#                                   la_name                age  \
# 307          Bath and North East Somerset        3-year-olds
# 314   Bournemouth, Christchurch and Poole        3-year-olds
# 319                      Bristol, City of        3-year-olds
# 330                              Cornwall        3-year-olds
# 338                                 Devon        3-year-olds
# 340                                Dorset        3-year-olds
# 348                       Gloucestershire        3-year-olds
# 363                       Isles of Scilly        3-year-olds
# 390                        North Somerset        3-year-olds
# 400                              Plymouth        3-year-olds
# 416                              Somerset        3-year-olds
# 417                 South Gloucestershire        3-year-olds
# 431                               Swindon        3-year-olds
# 435                                Torbay        3-year-olds
# ...

# %% [markdown]
# ## Replotting the graphs without the extreme outlier for Isles of Scilly

# %% [markdown]
# ## Percentage of Eligible 3 and 4 year Olds Enrolled in Childcare in 2020

# %%
#redefining percentage_eligible for 2020 without the extreme outlier
percent_eligible_per_region_2020 = pd.DataFrame(joined_15.loc[(joined_15["time_period"] == '2020') & (joined_15["age"] == '3 and 4-year-olds'), ["region_name","percentage_eligible_children"]])

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(
    data= percent_eligible_per_region_2020, 
    x = "percentage_eligible_children",
    y = "region_name",
    hue = "region_name"
)

plt.title('Percentage of Eligible 3 and 4-Year-Olds Enrolled in Childcare (2020)', fontsize=14)
plt.xlabel('Percentage of Eligible Children', fontsize=12)
plt.ylabel('Region', fontsize=12)
# Out:
# Text(0, 0.5, 'Region')

# %%
percent_eligible_per_region_2020.groupby("region_name").count()
# Out:
#                           percentage_eligible_children
# region_name
# East Midlands                                        9
# East of England                                     11
# Inner London                                        14
# North East                                          12
# North West                                          23
# Outer London                                        19
# South East                                          19
# South West                                          14
# West Midlands                                       14
# Yorkshire and The Humber                            15

# %%
percent_eligible_per_region_2020.groupby("region_name").agg({"percentage_eligible_children": "describe"})
# Out:
#                          percentage_eligible_children                        \
#                                                 count       mean        std
# region_name
# East Midlands                                     9.0  93.655556   2.884056
# East of England                                  11.0  92.445455   2.573466
# Inner London                                     14.0  76.492857  11.971470
# North East                                       12.0  98.058333   3.341055
# North West                                       23.0  95.834783   3.346859
# Outer London                                     19.0  88.047368   6.507122
# South East                                       19.0  93.205263   3.262323
# South West                                       14.0  95.207143   3.088556
# West Midlands                                    14.0  95.207143   5.034262
# Yorkshire and The Humber                         15.0  95.446667   2.689362
#
#
# ...

# %%
percent_eligible_median_per_region= percent_eligible_per_region_2020.groupby("region_name").agg({"percentage_eligible_children": "median"}).reset_index()

# %%
percent_eligible_median_per_region
# Out:
#                 region_name  percentage_eligible_children
# 0             East Midlands                         93.90
# 1           East of England                         93.50
# 2              Inner London                         80.65
# 3                North East                         97.05
# 4                North West                         96.20
# 5              Outer London                         87.50
# 6                South East                         93.20
# 7                South West                         95.25
# 8             West Midlands                         95.80
# 9  Yorkshire and The Humber                         95.40

# %%
percent_eligible_median_per_region.sort_values("percentage_eligible_children", ascending=False)
# Out:
#                 region_name  percentage_eligible_children
# 3                North East                         97.05
# 4                North West                         96.20
# 8             West Midlands                         95.80
# 9  Yorkshire and The Humber                         95.40
# 7                South West                         95.25
# 0             East Midlands                         93.90
# 1           East of England                         93.50
# 6                South East                         93.20
# 5              Outer London                         87.50
# 2              Inner London                         80.65

# %%
#data["difference"] = data["2019"] - data["2020"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[196], line 1
# ----> 1 data["difference"] = data["2019"] - data["2020"]
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## Percentage of Eligible 3 and 4 year Olds Enrolled in Childcare in 2021

# %%
#redefining percentage_eligible for 2021 without the extreme outlier
percent_eligible_per_region_2021 = pd.DataFrame(joined_15.loc[(joined_15["time_period"] == '2021') & (joined_15["age"] == '3 and 4-year-olds'), ["region_name","percentage_eligible_children"]])

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(
    data= percent_eligible_per_region_2021, 
    x = "percentage_eligible_children",
    y = "region_name",
    hue = "region_name"
)

plt.title('Percentage of Eligible 3 and 4-Year-Olds Enrolled in Childcare (2021)', fontsize=14)
plt.xlabel('Percentage of Eligible Children', fontsize=12)
plt.ylabel('Region', fontsize=12)
# Out:
# Text(0, 0.5, 'Region')

# %%
percent_eligible_per_region_2021.groupby("region_name").agg({"percentage_eligible_children": "describe"})
# Out:
#                          percentage_eligible_children                        \
#                                                 count       mean        std
# region_name
# East Midlands                                     9.0  90.888889   3.086035
# East of England                                  11.0  88.400000   3.187789
# Inner London                                     14.0  72.571429  14.107686
# North East                                       12.0  95.808333   3.108188
# North West                                       23.0  93.073913   3.143712
# Outer London                                     19.0  83.710526   6.239114
# South East                                       19.0  90.263158   4.509645
# South West                                       15.0  94.160000   6.021723
# West Midlands                                    14.0  91.235714   5.210287
# Yorkshire and The Humber                         15.0  92.026667   3.104482
#
#
# ...
