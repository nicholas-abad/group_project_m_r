# %%
import pandas as pd
import numpy as np
sen = pd.read_csv("/Users/vardr.DESKTOP-R06GCLK/CodeOp_Data_Analytics_Mod3on/Group_Project/UK_ed_under_5/data/4_early_years_provision_ethnicity_sen_2018_2024.csv")

# %%
sen
# Out:
#         time_period time_identifier geographic_level country_code  \
# 0              2024  Reporting year         National    E92000001
# 1              2024  Reporting year         National    E92000001
# 2              2024  Reporting year         National    E92000001
# 3              2024  Reporting year         National    E92000001
# 4              2024  Reporting year         National    E92000001
# ...             ...             ...              ...          ...
# 255695         2018  Reporting year  Local authority    E92000001
# 255696         2018  Reporting year  Local authority    E92000001
# 255697         2018  Reporting year  Local authority    E92000001
# 255698         2018  Reporting year  Local authority    E92000001
# 255699         2018  Reporting year  Local authority    E92000001
#
#        country_name region_code   region_name  old_la_code new_la_code  \
# 0           England         NaN           NaN          NaN         NaN
# 1           England         NaN           NaN          NaN         NaN
# 2           England         NaN           NaN          NaN         NaN
# 3           England         NaN           NaN          NaN         NaN
# 4           England         NaN           NaN          NaN         NaN
# ...             ...         ...           ...          ...         ...
# 255695      England   E13000002  Outer London        320.0   E09000031
# 255696      England   E13000002  Outer London        320.0   E09000031
# 255697      England   E13000002  Outer London        320.0   E09000031
# 255698      England   E13000002  Outer London        320.0   E09000031
# 255699      England   E13000002  Outer London        320.0   E09000031
#
#                la_name     entitlement_type year_group                age  \
# 0                  NaN  15-hour entitlement      Total              Total
# 1                  NaN  15-hour entitlement      Total              Total
# 2                  NaN  15-hour entitlement      Total              Total
# 3                  NaN  15-hour entitlement      Total              Total
# 4                  NaN  15-hour entitlement      Total              Total
# ...                ...                  ...        ...                ...
# 255695  Waltham Forest  30-hour entitlement      Total  3 and 4-year-olds
# 255696  Waltham Forest  30-hour entitlement      Total  3 and 4-year-olds
# 255697  Waltham Forest  30-hour entitlement      Total  3 and 4-year-olds
# 255698  Waltham Forest  30-hour entitlement      Total  3 and 4-year-olds
# 255699  Waltham Forest  30-hour entitlement      Total  3 and 4-year-olds
#
#                               ethnicity_major                sen  \
# 0                                       Total              Total
# 1                                       Total  No identified SEN
# 2                                       Total                SEN
# 3                                       Total                SEN
# 4                                       Total                SEN
# ...                                       ...                ...
# 255695           Mixed/Multiple ethnic groups              Total
# 255696                    Asian/Asian British              Total
# 255697  Black/African/Caribbean/Black British              Total
# 255698                     Other ethnic group              Total
# 255699                                Unknown              Total
#
#        sen_provision number_children percentage_children
# 0              Total         1285393                 100
# 1              Total         1175455                91.4
# 2              Total          109938                 8.6
# 3        SEN support           90409                   7
# 4           EHC plan           19529                 1.5
# ...              ...             ...                 ...
# 255695         Total             182                13.3
# 255696         Total             140                10.2
# 255697         Total             193                14.1
# 255698         Total              57                 4.2
# 255699         Total             114                 8.3
#
# [255700 rows x 18 columns]

# %%
sen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255700 entries, 0 to 255699
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   time_period          255700 non-null  int64
#  1   time_identifier      255700 non-null  object
#  2   geographic_level     255700 non-null  object
#  3   country_code         255700 non-null  object
#  4   country_name         255700 non-null  object
#  5   region_code          250800 non-null  object
#  6   region_name          250800 non-null  object
#  7   old_la_code          233860 non-null  float64
#  8   new_la_code          233860 non-null  object
#  9   la_name              233860 non-null  object
#  10  entitlement_type     255700 non-null  object
#  11  year_group           255700 non-null  object
#  12  age                  255700 non-null  object
#  13  ethnicity_major      255700 non-null  object
#  14  sen                  255700 non-null  object
#  15  sen_provision        255700 non-null  object
#  16  number_children      255700 non-null  object
#  17  percentage_children  255700 non-null  object
# dtypes: float64(1), int64(1), object(16)
# memory usage: 35.1+ MB

# %%
def display_unique_vals(df):
    for column in df.columns:
        unique_values = df[column].unique()
        print(f' Column: {column}')
        print(f'Number of unique values: {len(unique_values)}')
        print(f'Unique values: {unique_values}')
        print('-' * 40)

# %%
display_unique_vals(sen)
# Out:
#  Column: time_period
# Number of unique values: 7
# Unique values: [2024 2023 2022 2021 2020 2019 2018]
# ----------------------------------------
#  Column: time_identifier
# Number of unique values: 1
# Unique values: ['Reporting year']
# ----------------------------------------
#  Column: geographic_level
# Number of unique values: 3
# Unique values: ['National' 'Regional' 'Local authority']
# ----------------------------------------
#  Column: country_code
# Number of unique values: 1
# Unique values: ['E92000001']
# ----------------------------------------
#  Column: country_name
# Number of unique values: 1
# Unique values: ['England']
# ----------------------------------------
#  Column: region_code
# Number of unique values: 12
# Unique values: [nan 'E12000001' 'E12000002' 'E12000003' 'E12000004' 'E12000005'
#  'E12000006' 'E12000007' 'E12000008' 'E12000009' 'E13000001' 'E13000002']
# ----------------------------------------
#  Column: region_name
# Number of unique values: 12
# Unique values: [nan 'North East' 'North West' 'Yorkshire and The Humber' 'East Midlands'
#  'West Midlands' 'East of England' 'London' 'South East' 'South West'
#  'Inner London' 'Outer London']
# ----------------------------------------
#  Column: old_la_code
# Number of unique values: 159
# Unique values: [ nan 840. 841. 390. 805. 806. 391. 392. 929. 807. 393. 808. 394. 889.
#  890. 350. 351. 895. 896. 942. 876. 340. 888. 341. 352. 353. 354. 355.
#  343. 342. 356. 357. 358. 877. 943. 359. 344. 370. 380. 381. 371. 811.
#  810. 382. 383. 812. 813. 815. 372. 373. 384. 816. 831. 830. 856. 855.
#  925. 940. 892. 891. 857. 941. 330. 331. 332. 884. 333. 893. 334. 860.
#  861. 894. 335. 937. 336. 885. 822. 873. 823. 881. 919. 821. 926. 874.
#  882. 935. 883. 867. 846. 825. 845. 850. 921. 886. 887. 826. 931. 851.
#  870. 871. 852. 936. 869. 938. 868. 872. 800. 839. 801. 908. 878. 838.
#  916. 420. 802. 879. 933. 803. 866. 880. 865. 202. 201. 204. 205. 309.
#  206. 207. 208. 209. 316. 210. 211. 212. 213. 301. 302. 303. 304. 305.
#  306. 307. 308. 203. 310. 311. 312. 313. 314. 315. 317. 318. 319. 320.
#  909. 928. 837. 835. 836.]
# ----------------------------------------
#  Column: new_la_code
# Number of unique values: 160
# Unique values: [nan 'E06000047' 'E06000005' 'E08000037' 'E06000001' 'E06000002'
#  'E08000021' 'E08000022' 'E06000057' 'E06000003' 'E08000023' 'E06000004'
#  'E08000024' 'E06000008' 'E06000009' 'E08000001' 'E08000002' 'E06000049'
#  'E06000050' 'E06000063' 'E06000006' 'E08000011' 'E10000017' 'E08000012'
#  'E08000003' 'E08000004' 'E08000005' 'E08000006' 'E08000014' 'E08000013'
#  'E08000007' 'E08000008' 'E08000009' 'E06000007' 'E06000064' 'E08000010'
#  'E08000015' 'E08000016' 'E08000032' 'E08000033' 'E08000017' 'E06000011'
#  'E06000010' 'E08000034' 'E08000035' 'E06000012' 'E06000013' 'E10000023'
#  'E08000018' 'E08000019' 'E08000036' 'E06000014' 'E06000015' 'E10000007'
#  'E06000016' 'E10000018' 'E10000019' 'E06000061' 'E06000018' 'E10000024'
#  'E06000017' 'E06000062' 'E08000025' 'E08000026' 'E08000027' 'E06000019'
#  'E08000028' 'E06000051' 'E08000029' 'E10000028' 'E06000021' 'E06000020'
#  'E08000030' 'E10000031' 'E08000031' 'E10000034' 'E06000055' 'E10000003'
#  'E06000056' 'E10000012' 'E10000015' 'E06000032' 'E10000020' 'E06000031'
#  'E06000033' 'E10000029' 'E06000034' 'E06000036' 'E06000043' 'E06000060'
#  'E10000011' 'E10000014' 'E06000046' 'E10000016' 'E06000035' 'E06000042'
#  'E10000025' 'E06000044' 'E06000038' 'E06000039' 'E06000045' 'E10000030'
#  'E06000037' 'E10000032' 'E06000040' 'E06000041' 'E06000022' 'E06000058'
#  'E06000023' 'E06000052' 'E10000008' 'E06000059' 'E10000013' 'E06000053'
#  'E06000024' 'E06000026' 'E10000027' 'E06000025' 'E06000030' 'E06000027'
#  'E06000054' 'E09000007' 'E09000001' 'E09000012' 'E09000013' 'E09000014'
#  'E09000019' 'E09000020' 'E09000022' 'E09000023' 'E09000025' 'E09000028'
#  'E09000030' 'E09000032' 'E09000033' 'E09000002' 'E09000003' 'E09000004'
#  'E09000005' 'E09000006' 'E09000008' 'E09000009' 'E09000010' 'E09000011'
#  'E09000015' 'E09000016' 'E09000017' 'E09000018' 'E09000021' 'E09000024'
#  'E09000026' 'E09000027' 'E09000029' 'E09000031' 'E10000006' 'E10000021'
#  'E10000002' 'E06000028' 'E10000009' 'E06000029']
# ----------------------------------------
#  Column: la_name
# Number of unique values: 158
# Unique values: [nan 'County Durham' 'Darlington' 'Gateshead' 'Hartlepool' 'Middlesbrough'
#  'Newcastle upon Tyne' 'North Tyneside' 'Northumberland'
#  'Redcar and Cleveland' 'South Tyneside' 'Stockton-on-Tees' 'Sunderland'
#  'Blackburn with Darwen' 'Blackpool' 'Bolton' 'Bury' 'Cheshire East'
#  'Cheshire West and Chester' 'Cumberland' 'Halton' 'Knowsley' 'Lancashire'
#  'Liverpool' 'Manchester' 'Oldham' 'Rochdale' 'Salford' 'Sefton'
#  'St. Helens' 'Stockport' 'Tameside' 'Trafford' 'Warrington'
#  'Westmorland and Furness' 'Wigan' 'Wirral' 'Barnsley' 'Bradford'
#  'Calderdale' 'Doncaster' 'East Riding of Yorkshire'
#  'Kingston upon Hull, City of' 'Kirklees' 'Leeds'
#  'North East Lincolnshire' 'North Lincolnshire' 'North Yorkshire'
#  'Rotherham' 'Sheffield' 'Wakefield' 'York' 'Derby' 'Derbyshire'
#  'Leicester' 'Leicestershire' 'Lincolnshire' 'North Northamptonshire'
#  'Nottingham' 'Nottinghamshire' 'Rutland' 'West Northamptonshire'
#  'Birmingham' 'Coventry' 'Dudley' 'Herefordshire, County of' 'Sandwell'
#  'Shropshire' 'Solihull' 'Staffordshire' 'Stoke-on-Trent'
#  'Telford and Wrekin' 'Walsall' 'Warwickshire' 'Wolverhampton'
#  'Worcestershire' 'Bedford' 'Cambridgeshire' 'Central Bedfordshire'
#  'Essex' 'Hertfordshire' 'Luton' 'Norfolk' 'Peterborough'
#  'Southend-on-Sea' 'Suffolk' 'Thurrock' 'Bracknell Forest'
#  'Brighton and Hove' 'Buckinghamshire' 'East Sussex' 'Hampshire'
#  'Isle of Wight' 'Kent' 'Medway' 'Milton Keynes' 'Oxfordshire'
#  'Portsmouth' 'Reading' 'Slough' 'Southampton' 'Surrey' 'West Berkshire'
#  'West Sussex' 'Windsor and Maidenhead' 'Wokingham'
#  'Bath and North East Somerset' 'Bournemouth, Christchurch and Poole'
#  'Bristol, City of' 'Cornwall' 'Devon' 'Dorset' 'Gloucestershire'
#  'Isles of Scilly' 'North Somerset' 'Plymouth' 'Somerset'
#  'South Gloucestershire' 'Swindon' 'Torbay' 'Wiltshire' 'Camden'
#  'City of London' 'Hackney' 'Hammersmith and Fulham' 'Haringey'
#  'Islington' 'Kensington and Chelsea' 'Lambeth' 'Lewisham' 'Newham'
#  'Southwark' 'Tower Hamlets' 'Wandsworth' 'Westminster'
#  'Barking and Dagenham' 'Barnet' 'Bexley' 'Brent' 'Bromley' 'Croydon'
#  'Ealing' 'Enfield' 'Greenwich' 'Harrow' 'Havering' 'Hillingdon'
#  'Hounslow' 'Kingston upon Thames' 'Merton' 'Redbridge'
#  'Richmond upon Thames' 'Sutton' 'Waltham Forest' 'Cumbria'
#  'Northamptonshire' 'Bournemouth' 'Poole']
# ----------------------------------------
#  Column: entitlement_type
# Number of unique values: 2
# Unique values: ['15-hour entitlement' '30-hour entitlement']
# ----------------------------------------
#  Column: year_group
# Number of unique values: 3
# Unique values: ['Total' 'Nursery' 'Reception']
# ----------------------------------------
#  Column: age
# Number of unique values: 5
# Unique values: ['Total' '2-year-olds' '3-year-olds' '4-year-olds' '3 and 4-year-olds']
# ----------------------------------------
#  Column: ethnicity_major
# Number of unique values: 7
# Unique values: ['Total' 'White' 'Mixed/Multiple ethnic groups' 'Asian/Asian British'
#  'Black/African/Caribbean/Black British' 'Other ethnic group' 'Unknown']
# ----------------------------------------
#  Column: sen
# Number of unique values: 3
# Unique values: ['Total' 'No identified SEN' 'SEN']
# ----------------------------------------
#  Column: sen_provision
# Number of unique values: 3
# Unique values: ['Total' 'SEN support' 'EHC plan']
# ----------------------------------------
#  Column: number_children
# Number of unique values: 15124
# Unique values: ['1285393' '1175455' '109938' ... '6329' '3651' '7878']
# ----------------------------------------
#  Column: percentage_children
# Number of unique values: 1003
# Unique values: ['100' '91.4' '8.6' ... '53.4' '43.1' '33.4']
# ----------------------------------------

# %%
for column in sen.columns:
    print(column, sen[column].isnull().sum())
# Out:
# time_period 0
# time_identifier 0
# geographic_level 0
# country_code 0
# country_name 0
# region_code 4900
# region_name 4900
# old_la_code 21840
# new_la_code 21840
# la_name 21840
# entitlement_type 0
# year_group 0
# age 0
# ethnicity_major 0
# sen 0
# sen_provision 0
# number_children 0
# percentage_children 0

# %% [markdown]
# ## Changing time_period to datetime

# %%
sen["time_period"] = pd.to_datetime(sen["time_period"], format = "%Y")

# %%
sen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255700 entries, 0 to 255699
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   time_period          255700 non-null  datetime64[ns]
#  1   time_identifier      255700 non-null  object
#  2   geographic_level     255700 non-null  object
#  3   country_code         255700 non-null  object
#  4   country_name         255700 non-null  object
#  5   region_code          250800 non-null  object
#  6   region_name          250800 non-null  object
#  7   old_la_code          233860 non-null  float64
#  8   new_la_code          233860 non-null  object
#  9   la_name              233860 non-null  object
#  10  entitlement_type     255700 non-null  object
#  11  year_group           255700 non-null  object
#  12  age                  255700 non-null  object
#  13  ethnicity_major      255700 non-null  object
#  14  sen                  255700 non-null  object
#  15  sen_provision        255700 non-null  object
#  16  number_children      255700 non-null  object
#  17  percentage_children  255700 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(16)
# memory usage: 35.1+ MB

# %% [markdown]
# ## Removing all National and Regional Totals

# %%
sen = sen.dropna(how ="any" , subset = ["new_la_code"])

# %%
sen
# Out:
#        time_period time_identifier geographic_level country_code country_name  \
# 3120    2024-01-01  Reporting year  Local authority    E92000001      England
# 3121    2024-01-01  Reporting year  Local authority    E92000001      England
# 3122    2024-01-01  Reporting year  Local authority    E92000001      England
# 3123    2024-01-01  Reporting year  Local authority    E92000001      England
# 3124    2024-01-01  Reporting year  Local authority    E92000001      England
# ...            ...             ...              ...          ...          ...
# 255695  2018-01-01  Reporting year  Local authority    E92000001      England
# 255696  2018-01-01  Reporting year  Local authority    E92000001      England
# 255697  2018-01-01  Reporting year  Local authority    E92000001      England
# 255698  2018-01-01  Reporting year  Local authority    E92000001      England
# 255699  2018-01-01  Reporting year  Local authority    E92000001      England
#
#        region_code   region_name  old_la_code new_la_code         la_name  \
# 3120     E12000001    North East        840.0   E06000047   County Durham
# 3121     E12000001    North East        840.0   E06000047   County Durham
# 3122     E12000001    North East        840.0   E06000047   County Durham
# 3123     E12000001    North East        840.0   E06000047   County Durham
# 3124     E12000001    North East        840.0   E06000047   County Durham
# ...            ...           ...          ...         ...             ...
# 255695   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 255696   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 255697   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 255698   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 255699   E13000002  Outer London        320.0   E09000031  Waltham Forest
#
#            entitlement_type year_group                age  \
# 3120    15-hour entitlement      Total              Total
# 3121    15-hour entitlement      Total              Total
# 3122    15-hour entitlement      Total              Total
# 3123    15-hour entitlement      Total              Total
# 3124    15-hour entitlement      Total              Total
# ...                     ...        ...                ...
# 255695  30-hour entitlement      Total  3 and 4-year-olds
# 255696  30-hour entitlement      Total  3 and 4-year-olds
# 255697  30-hour entitlement      Total  3 and 4-year-olds
# 255698  30-hour entitlement      Total  3 and 4-year-olds
# 255699  30-hour entitlement      Total  3 and 4-year-olds
#
#                               ethnicity_major                sen  \
# 3120                                    Total              Total
# 3121                                    Total  No identified SEN
# 3122                                    Total                SEN
# 3123                                    Total                SEN
# 3124                                    Total                SEN
# ...                                       ...                ...
# 255695           Mixed/Multiple ethnic groups              Total
# 255696                    Asian/Asian British              Total
# 255697  Black/African/Caribbean/Black British              Total
# 255698                     Other ethnic group              Total
# 255699                                Unknown              Total
#
#        sen_provision number_children percentage_children
# 3120           Total           11123                 100
# 3121           Total            9971                89.6
# 3122           Total            1152                10.4
# 3123     SEN support            1040                 9.3
# 3124        EHC plan             112                   1
# ...              ...             ...                 ...
# 255695         Total             182                13.3
# 255696         Total             140                10.2
# 255697         Total             193                14.1
# 255698         Total              57                 4.2
# 255699         Total             114                 8.3
#
# [233860 rows x 18 columns]

# %% [markdown]
# ## Keep only "Total" rows from year_group, ethnicity_major and sen_provider

# %%
sen["sen_provision"].value_counts(dropna=False)
# Out:
# sen_provision
# Total          191340
# SEN support     21260
# EHC plan        21260
# Name: count, dtype: int64

# %% [markdown]
# #### Tried many many ways to make a function here but with the clock running I decided to do it the unsophisticated way

# %%
sen = keep_total = sen[sen["year_group"] == 'Total']

# %%
sen = keep_total_sen_provision = sen[sen["sen_provision"] == 'Total']

# %%
sen
# Out:
#        time_period time_identifier geographic_level country_code country_name  \
# 3120    2024-01-01  Reporting year  Local authority    E92000001      England
# 3121    2024-01-01  Reporting year  Local authority    E92000001      England
# 3122    2024-01-01  Reporting year  Local authority    E92000001      England
# 3125    2024-01-01  Reporting year  Local authority    E92000001      England
# 3126    2024-01-01  Reporting year  Local authority    E92000001      England
# ...            ...             ...              ...          ...          ...
# 255695  2018-01-01  Reporting year  Local authority    E92000001      England
# 255696  2018-01-01  Reporting year  Local authority    E92000001      England
# 255697  2018-01-01  Reporting year  Local authority    E92000001      England
# 255698  2018-01-01  Reporting year  Local authority    E92000001      England
# 255699  2018-01-01  Reporting year  Local authority    E92000001      England
#
#        region_code   region_name  old_la_code new_la_code         la_name  \
# 3120     E12000001    North East        840.0   E06000047   County Durham
# 3121     E12000001    North East        840.0   E06000047   County Durham
# 3122     E12000001    North East        840.0   E06000047   County Durham
# 3125     E12000001    North East        840.0   E06000047   County Durham
# 3126     E12000001    North East        840.0   E06000047   County Durham
# ...            ...           ...          ...         ...             ...
# 255695   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 255696   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 255697   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 255698   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 255699   E13000002  Outer London        320.0   E09000031  Waltham Forest
#
#            entitlement_type year_group                age  \
# 3120    15-hour entitlement      Total              Total
# 3121    15-hour entitlement      Total              Total
# 3122    15-hour entitlement      Total              Total
# 3125    15-hour entitlement      Total              Total
# 3126    15-hour entitlement      Total              Total
# ...                     ...        ...                ...
# 255695  30-hour entitlement      Total  3 and 4-year-olds
# 255696  30-hour entitlement      Total  3 and 4-year-olds
# 255697  30-hour entitlement      Total  3 and 4-year-olds
# 255698  30-hour entitlement      Total  3 and 4-year-olds
# 255699  30-hour entitlement      Total  3 and 4-year-olds
#
#                               ethnicity_major                sen  \
# 3120                                    Total              Total
# 3121                                    Total  No identified SEN
# 3122                                    Total                SEN
# 3125                                    White              Total
# 3126             Mixed/Multiple ethnic groups              Total
# ...                                       ...                ...
# 255695           Mixed/Multiple ethnic groups              Total
# 255696                    Asian/Asian British              Total
# 255697  Black/African/Caribbean/Black British              Total
# 255698                     Other ethnic group              Total
# 255699                                Unknown              Total
#
#        sen_provision number_children percentage_children
# 3120           Total           11123                 100
# 3121           Total            9971                89.6
# 3122           Total            1152                10.4
# 3125           Total            8578                77.1
# 3126           Total             204                 1.8
# ...              ...             ...                 ...
# 255695         Total             182                13.3
# 255696         Total             140                10.2
# 255697         Total             193                14.1
# 255698         Total              57                 4.2
# 255699         Total             114                 8.3
#
# [95670 rows x 18 columns]

# %%
sen["year_group"].value_counts(dropna=False)
# Out:
# year_group
# Total    95670
# Name: count, dtype: int64

# %%
sen["sen_provision"].value_counts(dropna=False)
# Out:
# sen_provision
# Total    95670
# Name: count, dtype: int64

# %%
sen["ethnicity_major"].value_counts(dropna=False)
# Out:
# ethnicity_major
# Total                                    31890
# White                                    10630
# Mixed/Multiple ethnic groups             10630
# Asian/Asian British                      10630
# Black/African/Caribbean/Black British    10630
# Other ethnic group                       10630
# Unknown                                  10630
# Name: count, dtype: int64

# %%
sen = keep_total_ethnicity = sen[sen["ethnicity_major"] == 'Total']

# %%
sen
# Out:
#        time_period time_identifier geographic_level country_code country_name  \
# 3120    2024-01-01  Reporting year  Local authority    E92000001      England
# 3121    2024-01-01  Reporting year  Local authority    E92000001      England
# 3122    2024-01-01  Reporting year  Local authority    E92000001      England
# 3131    2024-01-01  Reporting year  Local authority    E92000001      England
# 3132    2024-01-01  Reporting year  Local authority    E92000001      England
# ...            ...             ...              ...          ...          ...
# 255679  2018-01-01  Reporting year  Local authority    E92000001      England
# 255680  2018-01-01  Reporting year  Local authority    E92000001      England
# 255689  2018-01-01  Reporting year  Local authority    E92000001      England
# 255690  2018-01-01  Reporting year  Local authority    E92000001      England
# 255691  2018-01-01  Reporting year  Local authority    E92000001      England
#
#        region_code   region_name  old_la_code new_la_code         la_name  \
# 3120     E12000001    North East        840.0   E06000047   County Durham
# 3121     E12000001    North East        840.0   E06000047   County Durham
# 3122     E12000001    North East        840.0   E06000047   County Durham
# 3131     E12000001    North East        840.0   E06000047   County Durham
# 3132     E12000001    North East        840.0   E06000047   County Durham
# ...            ...           ...          ...         ...             ...
# 255679   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 255680   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 255689   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 255690   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 255691   E13000002  Outer London        320.0   E09000031  Waltham Forest
#
#            entitlement_type year_group                age ethnicity_major  \
# 3120    15-hour entitlement      Total              Total           Total
# 3121    15-hour entitlement      Total              Total           Total
# 3122    15-hour entitlement      Total              Total           Total
# 3131    15-hour entitlement      Total        2-year-olds           Total
# 3132    15-hour entitlement      Total        2-year-olds           Total
# ...                     ...        ...                ...             ...
# 255679  30-hour entitlement      Total        4-year-olds           Total
# 255680  30-hour entitlement      Total        4-year-olds           Total
# 255689  30-hour entitlement      Total  3 and 4-year-olds           Total
# 255690  30-hour entitlement      Total  3 and 4-year-olds           Total
# 255691  30-hour entitlement      Total  3 and 4-year-olds           Total
#
#                       sen sen_provision number_children percentage_children
# 3120                Total         Total           11123                 100
# 3121    No identified SEN         Total            9971                89.6
# 3122                  SEN         Total            1152                10.4
# 3131                Total         Total            1370                 100
# 3132    No identified SEN         Total            1288                  94
# ...                   ...           ...             ...                 ...
# 255679  No identified SEN         Total             342                96.1
# 255680                SEN         Total              14                 3.9
# 255689              Total         Total            1371                 100
# 255690  No identified SEN         Total            1310                95.6
# 255691                SEN         Total              61                 4.4
#
# [31890 rows x 18 columns]

# %%
sen["ethnicity_major"].value_counts(dropna=False)
# Out:
# ethnicity_major
# Total    31890
# Name: count, dtype: int64

# %% [markdown]
# ## Edit age: remove total, 2 year olds from age column

# %%
def filter_out_age(df):
    """
    Removes rows where the column 'age' contains specific unwanted values.
    Parameters:
    df: The DataFrame to modify
    Returns:
    pandas.DataFrame: The modified DataFrame with rows removed.
    """
    unwanted_values = ['2-year-olds', 'Total']
    if 'age' in df.columns:
        return df[~df['age'].isin(unwanted_values)].reset_index(drop=True)

# %%
sen = filter_out_age(sen)

# %%
sen
# Out:
#       time_period time_identifier geographic_level country_code country_name  \
# 0      2024-01-01  Reporting year  Local authority    E92000001      England
# 1      2024-01-01  Reporting year  Local authority    E92000001      England
# 2      2024-01-01  Reporting year  Local authority    E92000001      England
# 3      2024-01-01  Reporting year  Local authority    E92000001      England
# 4      2024-01-01  Reporting year  Local authority    E92000001      England
# ...           ...             ...              ...          ...          ...
# 19129  2018-01-01  Reporting year  Local authority    E92000001      England
# 19130  2018-01-01  Reporting year  Local authority    E92000001      England
# 19131  2018-01-01  Reporting year  Local authority    E92000001      England
# 19132  2018-01-01  Reporting year  Local authority    E92000001      England
# 19133  2018-01-01  Reporting year  Local authority    E92000001      England
#
#       region_code   region_name  old_la_code new_la_code         la_name  \
# 0       E12000001    North East        840.0   E06000047   County Durham
# 1       E12000001    North East        840.0   E06000047   County Durham
# 2       E12000001    North East        840.0   E06000047   County Durham
# 3       E12000001    North East        840.0   E06000047   County Durham
# 4       E12000001    North East        840.0   E06000047   County Durham
# ...           ...           ...          ...         ...             ...
# 19129   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 19130   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 19131   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 19132   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 19133   E13000002  Outer London        320.0   E09000031  Waltham Forest
#
#           entitlement_type year_group                age ethnicity_major  \
# 0      15-hour entitlement      Total        3-year-olds           Total
# 1      15-hour entitlement      Total        3-year-olds           Total
# 2      15-hour entitlement      Total        3-year-olds           Total
# 3      15-hour entitlement      Total        4-year-olds           Total
# 4      15-hour entitlement      Total        4-year-olds           Total
# ...                    ...        ...                ...             ...
# 19129  30-hour entitlement      Total        4-year-olds           Total
# 19130  30-hour entitlement      Total        4-year-olds           Total
# 19131  30-hour entitlement      Total  3 and 4-year-olds           Total
# 19132  30-hour entitlement      Total  3 and 4-year-olds           Total
# 19133  30-hour entitlement      Total  3 and 4-year-olds           Total
#
#                      sen sen_provision number_children percentage_children
# 0                  Total         Total            4752                 100
# 1      No identified SEN         Total            4376                92.1
# 2                    SEN         Total             376                 7.9
# 3                  Total         Total            5001                 100
# 4      No identified SEN         Total            4307                86.1
# ...                  ...           ...             ...                 ...
# 19129  No identified SEN         Total             342                96.1
# 19130                SEN         Total              14                 3.9
# 19131              Total         Total            1371                 100
# 19132  No identified SEN         Total            1310                95.6
# 19133                SEN         Total              61                 4.4
#
# [19134 rows x 18 columns]

# %% [markdown]
# ## Keep only value 'sen' under "sen" column

# %%
sen = keep_sen_only = sen[sen["sen"] == 'SEN']

# %%
sen
# Out:
#       time_period time_identifier geographic_level country_code country_name  \
# 2      2024-01-01  Reporting year  Local authority    E92000001      England
# 5      2024-01-01  Reporting year  Local authority    E92000001      England
# 8      2024-01-01  Reporting year  Local authority    E92000001      England
# 11     2024-01-01  Reporting year  Local authority    E92000001      England
# 14     2024-01-01  Reporting year  Local authority    E92000001      England
# ...           ...             ...              ...          ...          ...
# 19121  2018-01-01  Reporting year  Local authority    E92000001      England
# 19124  2018-01-01  Reporting year  Local authority    E92000001      England
# 19127  2018-01-01  Reporting year  Local authority    E92000001      England
# 19130  2018-01-01  Reporting year  Local authority    E92000001      England
# 19133  2018-01-01  Reporting year  Local authority    E92000001      England
#
#       region_code   region_name  old_la_code new_la_code         la_name  \
# 2       E12000001    North East        840.0   E06000047   County Durham
# 5       E12000001    North East        840.0   E06000047   County Durham
# 8       E12000001    North East        840.0   E06000047   County Durham
# 11      E12000001    North East        840.0   E06000047   County Durham
# 14      E12000001    North East        840.0   E06000047   County Durham
# ...           ...           ...          ...         ...             ...
# 19121   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 19124   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 19127   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 19130   E13000002  Outer London        320.0   E09000031  Waltham Forest
# 19133   E13000002  Outer London        320.0   E09000031  Waltham Forest
#
#           entitlement_type year_group                age ethnicity_major  sen  \
# 2      15-hour entitlement      Total        3-year-olds           Total  SEN
# 5      15-hour entitlement      Total        4-year-olds           Total  SEN
# 8      15-hour entitlement      Total  3 and 4-year-olds           Total  SEN
# 11     30-hour entitlement      Total        3-year-olds           Total  SEN
# 14     30-hour entitlement      Total        4-year-olds           Total  SEN
# ...                    ...        ...                ...             ...  ...
# 19121  15-hour entitlement      Total        4-year-olds           Total  SEN
# 19124  15-hour entitlement      Total  3 and 4-year-olds           Total  SEN
# 19127  30-hour entitlement      Total        3-year-olds           Total  SEN
# 19130  30-hour entitlement      Total        4-year-olds           Total  SEN
# 19133  30-hour entitlement      Total  3 and 4-year-olds           Total  SEN
#
#       sen_provision number_children percentage_children
# 2             Total             376                 7.9
# 5             Total             694                13.9
# 8             Total            1070                  11
# 11            Total             129                 5.2
# 14            Total              96                 9.9
# ...             ...             ...                 ...
# 19121         Total             411                11.1
# 19124         Total             646                   9
# 19127         Total              47                 4.6
# 19130         Total              14                 3.9
# 19133         Total              61                 4.4
#
# [6378 rows x 18 columns]

# %% [markdown]
# ## Replacing invalid values with NaNs [z, c, u, x, low]

# %%
sen["number_children"].value_counts(dropna=False)
# Out:
# number_children
# 17      76
# 13      71
# 18      70
# 20      68
# 14      67
#         ..
# 860      1
# 1046     1
# 1015     1
# 1496     1
# 758      1
# Name: count, Length: 948, dtype: int64

# %%
sen["number_children"].value_counts(dropna=False).get('z', 0)
# Out:
# 0

# %%
sen["percentage_children"].value_counts(dropna=False)
# Out:
# percentage_children
# 3.1     98
# 2.5     94
# 2.8     92
# 3.4     91
# 3       87
#         ..
# 20.9     1
# 17.6     1
# 21.4     1
# 20       1
# 16.4     1
# Name: count, Length: 175, dtype: int64

# %%
sen["percentage_children"].value_counts(dropna=False).get('z', 0)
# Out:
# 0

# %% [markdown]
# ## removing time_identifier, country_code, country_name and old_la_code from sen data

# %%
sen = sen.drop(
    ["time_identifier", "country_code","country_name", "old_la_code", "ethnicity_major", "sen", "sen_provision" ], axis = 1
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 sen = sen.drop(
#       2     ["time_identifier", "country_code","country_name", "old_la_code", "ethnicity_major", "sen", "sen_provision" ], axis = 1
#       3 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['time_identifier', 'country_code', 'country_name', 'old_la_code'] not found in axis"

# %%
sen = sen.drop(
    ["ethnicity_major", "sen", "sen_provision" ], axis = 1
)

# %%
sen = sen.drop(
    ["year_group" ], axis = 1
)

# %%
sen.rename(
    columns = {
        "number_children" : "number_children_sen",
        "percentage_children" : "percentage_children_sen",
    },
    inplace=True
)

# %%
sen
# Out:
#       time_period geographic_level region_code   region_name new_la_code  \
# 2      2024-01-01  Local authority   E12000001    North East   E06000047
# 5      2024-01-01  Local authority   E12000001    North East   E06000047
# 8      2024-01-01  Local authority   E12000001    North East   E06000047
# 11     2024-01-01  Local authority   E12000001    North East   E06000047
# 14     2024-01-01  Local authority   E12000001    North East   E06000047
# ...           ...              ...         ...           ...         ...
# 19121  2018-01-01  Local authority   E13000002  Outer London   E09000031
# 19124  2018-01-01  Local authority   E13000002  Outer London   E09000031
# 19127  2018-01-01  Local authority   E13000002  Outer London   E09000031
# 19130  2018-01-01  Local authority   E13000002  Outer London   E09000031
# 19133  2018-01-01  Local authority   E13000002  Outer London   E09000031
#
#               la_name     entitlement_type                age  \
# 2       County Durham  15-hour entitlement        3-year-olds
# 5       County Durham  15-hour entitlement        4-year-olds
# 8       County Durham  15-hour entitlement  3 and 4-year-olds
# 11      County Durham  30-hour entitlement        3-year-olds
# 14      County Durham  30-hour entitlement        4-year-olds
# ...               ...                  ...                ...
# 19121  Waltham Forest  15-hour entitlement        4-year-olds
# 19124  Waltham Forest  15-hour entitlement  3 and 4-year-olds
# 19127  Waltham Forest  30-hour entitlement        3-year-olds
# 19130  Waltham Forest  30-hour entitlement        4-year-olds
# 19133  Waltham Forest  30-hour entitlement  3 and 4-year-olds
#
#       number_children_sen percentage_children_sen
# 2                     376                     7.9
# 5                     694                    13.9
# 8                    1070                      11
# 11                    129                     5.2
# 14                     96                     9.9
# ...                   ...                     ...
# 19121                 411                    11.1
# 19124                 646                       9
# 19127                  47                     4.6
# 19130                  14                     3.9
# 19133                  61                     4.4
#
# [6378 rows x 10 columns]

# %%
sen.to_csv("/Users/vardr.DESKTOP-R06GCLK/CodeOp_Data_Analytics_Mod3on/Group_Project/Preprocessed files/sen.csv", sep=",", index=False, encoding="utf8")
